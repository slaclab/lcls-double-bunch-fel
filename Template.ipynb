# %% [markdown]
# # Lab Template
#
# - Date: Thursday 12 February 2022
# - People: Anatoly Krasnikh, Alex Halavanau, Agustin Romero
# - Location: SLAC Linac 21-5
#
# ## Materials and Methods
#
# ## Procedure
#
# ## Results

# %%
import h5py
from matplotlib import pyplot

file = '2022-01-12-17-51-14'

f = h5py.File(file,'r')

figure, ax = pyplot.subplots(dpi=100)

for index in range(1):
    x = f['awgscope_traces_x_CH1'][index]
    y = f['awgscope_traces_y_CH1'][index]

    ax.plot(x, y)

# %%
f['attrs'].attrs['comment']
# Out:
# 'long cable, kV 0.98'

# %%
x = f['pulserscope_traces_x'][1]
y = f['pulserscope_traces_y'][1]

pyplot.plot(x, y)
