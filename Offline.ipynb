# %% [markdown]
# Purpose: Offline analysis of saved data.

# %%
import h5py
from matplotlib import pyplot

file = '2021-11-24-03-44-43'

f = h5py.File(file,'r')

x = f['awgscope_traces_x'][0]
y = f['awgscope_traces_y'][0]

pyplot.plot(x, y)

# %%
x = f['pulserscope_traces_x'][0]
y = f['pulserscope_traces_y'][0]

pyplot.plot(x, y)
