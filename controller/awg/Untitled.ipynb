# %%
import pulse
import matplotlib.pyplot

lop = [pulse.PulseInfo(1, 1),
       pulse.PulseInfo(-0.7, -50),
       pulse.PulseInfo(-0.4, -100),
       pulse.PulseInfo(-0.9, -150)]
w = pulse.Waveform(lop)
y = w.get_waveform()
matplotlib.pyplot.plot(y[:400])
